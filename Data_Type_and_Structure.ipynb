# %%
def isPalindrome(x):
    return x== x[::-1]
 
 
x = "malam"
ans = isPalindrome(x)
 
if ans:
    print( (x) , 'is a polindrome')
else:
    print( (x) , 'is not a polindrome')
# Out:
# malam is a polindrome

# %%
def isPalindrome(x):
    return x== x[::-1]
 
 
x = "ABBA"
ans = isPalindrome(x)
 
if ans:
    print( (x) , 'is a polindrome')
else:
    print( (x) , 'is not a polindrome')
# Out:
# ABBA is a polindrome

# %%
def isPalindrome(y):
    return y == x[::-1]
 
 
x = "python"
ans = isPalindrome(x)
 
if ans:
    print( (x) , 'is a polindrome')
else:
    print( (x) , 'is not a polindrome')
# Out:
# python is not a polindrome

# %%
# Task 2

black_list_word = ['andi', 'susi', 'bola']
print(black_list_word)
# Out:
# ['andi', 'susi', 'bola']

# %%
black_list_word = ['andi', 'susi', 'bola']
kalimat = 'andi sedang makan nasi padang'

if any('andi' in word for word in black_list_word):
  print('ada di black list word')
else:
  print('tidak ada di black list word')
# Out:
# ada di black list word

# %%
black_list_word = ['andi', 'susi', 'bola']
kalimat = 'sandi sedang main tenis'

if any('sandi' in word for word in black_list_word):
  print('ada di black list word')
else:
  print('tidak ada di black list word')
# Out:
# tidak ada di black list word

# %%
black_list_word = ['andi', 'susi', 'bola']
kalimat = 'andi dan sandi sedang makan'

if any('andi' in word for word in black_list_word):
  print('ada di black list word')
else:
  print('tidak ada di black list word')
# Out:
# ada di black list word

# %%
black_list_word = ['andi', 'susi', 'bola']
kalimat = 'budi dan susi sedang makan'

if any('susi' in word for word in black_list_word):
  print('ada di black list word')
else:
  print('tidak ada di black list word')
# Out:
# ada di black list word

# %%
black_list_word = ['andi', 'susi', 'bola']
kalimat = 'erna sedang berenang'

if any('erna' in word for word in black_list_word):
  print('ada di black list word')
else:
  print('tidak ada di black list word')
# Out:
# tidak ada di black list word

# %%
black_list_word = ['andi', 'susi', 'bola']
kalimat = 'raffa sedang bermain bola'

if any('bola' in word for word in black_list_word):
  print('ada di black list word')
else:
  print('tidak ada di black list word')
# Out:
# ada di black list word
